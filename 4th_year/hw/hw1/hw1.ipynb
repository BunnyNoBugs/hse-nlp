# %%
import pandas as pd
import spacy
nlp = spacy.load("ru_core_news_lg")
import RAKE
from nltk.corpus import stopwords
STOPWORDS = stopwords.words('russian')
STOPWORDS.extend(['который'])
import summa
import gensim
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
from typing import List, Iterable, Dict

# %%
def preprocess_text(text):
    doc = nlp(text)
    lemmata = [token.lemma_ for token in doc]
    lemmata = ['который' if l.startswith('котор') else l for l in lemmata]
    return ' '.join(lemmata)

# %% [markdown]
# В качестве текстов были взяты новости с сайта [hse.ru](https://www.hse.ru/news/). В них уже выделены ключевые слова и/или тэги.
#
# Ключевые слова с сайта даны в колонке `original_keywords`, выделенные вручную -- в колонке `manual_keywords`. Количество пересечений в этих двух наборах ключевых слов -- в колонке `intersection`.

# %%
corpus = pd.read_csv('keywords_corpus.csv', sep=';')
corpus['lemmatized_text'] = corpus['text'].apply(preprocess_text)
corpus['original_keywords'] = corpus['original_keywords'].apply(lambda x: set(x.split(', ')))
corpus['manual_keywords'] = corpus['manual_keywords'].apply(lambda x: set(x.lower().split(', ')))
corpus['intersection'] = corpus.apply(lambda x: len(x['original_keywords'].intersection(x['manual_keywords'])), axis=1)
corpus
# Out:
#                                                 text  \
# 0  Завершились региональные кейс-чемпионаты школь...
# 1  Премьер-министр Михаил Мишустин предложил Ярос...
# 2  Сегодня публикацией предметного рейтинга «Иску...
# 3  Компания Яндекс создала консультативный совет ...
# 4  Абитуриентов ждет увеличение бюджетных мест, р...
# 5  До 5 ноября продолжается прием на совместную п...
# 6  29-30 октября в онлайн-формате пройдет юбилейн...
# 7  НИУ ВШЭ вручена ежегодная премия «Импульс добр...
#
#                                    original_keywords  \
# 0  {кейс-чемпионат школьников по экономике и пред...
# 1  {новое в ВШЭ, официально, экспертиза, идеи и о...
# 2  {официально, магистратура, рейтинг QS, рейтинг...
# 3              {профессора, экспертиза, идеи и опыт}
# 4  {новое в ВШЭ, официально, магистратура, разъяс...
# 5  {приглашение к участию, дополнительное образов...
# 6  {международное сотрудничество, международная к...
# 7  {репортаж о событии, достижения, социальное пр...
#
#                                      manual_keywords  \
# 0  {кейс-чемпионат школьников, предпринимательств...
# 1  {ярослав кузьминов, экспертиза, высшая школа э...
# 2  {предмет, академический рейтинг мировых универ...
# 3  {консультативный совет, ярослав кузьминов, экс...
# 4  {вступительные испытания, магистратура, обучен...
# 5  {спортивный, спортивный менеджмент, проект, сп...
# 6  {международное сотрудничество, финансовый, раб...
# 7  {фонд «наше будущее», социальный, «импульс доб...
#
#                                      lemmatized_text  intersection
# 0  завершиться региональный кейс - чемпионаты шко...             0
# 1  премьер - министр михаил мишустин предложить я...             1
# 2  сегодня публикация предметный рейтинг " искусс...             0
# 3  компания яндекс создать консультативный совет ...             1
# 4  абитуриент ждать увеличение бюджетный место , ...             2
# 5  до 5 ноябрь продолжаться приём на совместный п...             1
# 6  29 - 30 октябрь в онлайн - формате пройти юбил...             2
# 7  ниу вшэ вручить ежегодный премия " импульс доб...             1

# %% [markdown]
# Создадим эталон разметки, объединив ключевые слова, размеченные вручную, и ключевые слова с сайта, предварительно удалив из них те, что не встречаются в тексте. Эталон разметки находится в колонке `gold_keywords`.

# %%
corpus['original_keywords'] = corpus.apply(lambda x: [i for i in x['original_keywords'] if i in x['lemmatized_text']], axis=1)
corpus['original_keywords'] = corpus['original_keywords'].apply(set)
corpus['gold_keywords'] = corpus.apply(lambda x: x['original_keywords'].union(x['manual_keywords']), axis=1)
corpus
# Out:
#                                                 text  \
# 0  Завершились региональные кейс-чемпионаты школь...
# 1  Премьер-министр Михаил Мишустин предложил Ярос...
# 2  Сегодня публикацией предметного рейтинга «Иску...
# 3  Компания Яндекс создала консультативный совет ...
# 4  Абитуриентов ждет увеличение бюджетных мест, р...
# 5  До 5 ноября продолжается прием на совместную п...
# 6  29-30 октября в онлайн-формате пройдет юбилейн...
# 7  НИУ ВШЭ вручена ежегодная премия «Импульс добр...
#
#              original_keywords  \
# 0                           {}
# 1                 {экспертиза}
# 2                           {}
# 3                           {}
# 4  {бакалавриат, магистратура}
# 5                           {}
# 6                           {}
# 7                           {}
#
#                                      manual_keywords  \
# 0  {кейс-чемпионат школьников, предпринимательств...
# 1  {ярослав кузьминов, экспертиза, высшая школа э...
# 2  {предмет, академический рейтинг мировых универ...
# 3  {консультативный совет, ярослав кузьминов, экс...
# 4  {вступительные испытания, магистратура, обучен...
# 5  {спортивный, спортивный менеджмент, проект, сп...
# 6  {международное сотрудничество, финансовый, раб...
# 7  {фонд «наше будущее», социальный, «импульс доб...
#
#                                      lemmatized_text  intersection  \
# 0  завершиться региональный кейс - чемпионаты шко...             0
# 1  премьер - министр михаил мишустин предложить я...             1
# 2  сегодня публикация предметный рейтинг " искусс...             0
# 3  компания яндекс создать консультативный совет ...             1
# 4  абитуриент ждать увеличение бюджетный место , ...             2
# 5  до 5 ноябрь продолжаться приём на совместный п...             1
# 6  29 - 30 октябрь в онлайн - формате пройти юбил...             2
# 7  ниу вшэ вручить ежегодный премия " импульс доб...             1
#
#                                        gold_keywords
# 0  {кейс-чемпионат школьников, предпринимательств...
# 1  {ярослав кузьминов, экспертное сообщество, экс...
# 2  {предмет, академический рейтинг мировых универ...
# 3  {консультативный совет, ярослав кузьминов, экс...
# 4  {вступительные испытания, программа, бакалаври...
# 5  {спортивный, спортивный менеджмент, проект, сп...
# 6  {международное сотрудничество, финансовый, раб...
# 7  {фонд «наше будущее», социальный, «импульс доб...

# %% [markdown]
# ### RAKE

# %%
rake = RAKE.Rake(STOPWORDS)

# %%
corpus['rake_keywords'] = corpus['lemmatized_text'].apply(lambda x: [i[0] for i in rake.run(x, maxWords=3, minFrequency=2)])

# %% [markdown]
# ### TextRank

# %%
corpus['textrank_keywords'] = corpus['lemmatized_text'].apply(lambda x: summa.keywords.keywords(x, language='russian', 
                                                                                                additional_stopwords=STOPWORDS
                                                                                               ).split('\n'))

# %% [markdown]
# ### TF-IDF

# %%
vect = TfidfVectorizer(stop_words=STOPWORDS)

# %%
kw_idx = pd.Series(list(np.argsort(-vect.fit_transform(corpus['lemmatized_text']).toarray())))
corpus['tfidf_keywords'] = kw_idx.apply(lambda x: vect.get_feature_names_out()[x][:20])

# %%
corpus
# Out:
#                                                 text  \
# 0  Завершились региональные кейс-чемпионаты школь...
# 1  Премьер-министр Михаил Мишустин предложил Ярос...
# 2  Сегодня публикацией предметного рейтинга «Иску...
# 3  Компания Яндекс создала консультативный совет ...
# 4  Абитуриентов ждет увеличение бюджетных мест, р...
# 5  До 5 ноября продолжается прием на совместную п...
# 6  29-30 октября в онлайн-формате пройдет юбилейн...
# 7  НИУ ВШЭ вручена ежегодная премия «Импульс добр...
#
#              original_keywords  \
# 0                           {}
# 1                 {экспертиза}
# 2                           {}
# 3                           {}
# 4  {бакалавриат, магистратура}
# 5                           {}
# 6                           {}
# 7                           {}
#
#                                      manual_keywords  \
# 0  {кейс-чемпионат школьников, предпринимательств...
# 1  {ярослав кузьминов, экспертиза, высшая школа э...
# 2  {предмет, академический рейтинг мировых универ...
# 3  {консультативный совет, ярослав кузьминов, экс...
# 4  {вступительные испытания, магистратура, обучен...
# 5  {спортивный, спортивный менеджмент, проект, сп...
# 6  {международное сотрудничество, финансовый, раб...
# 7  {фонд «наше будущее», социальный, «импульс доб...
#
#                                      lemmatized_text  intersection  \
# 0  завершиться региональный кейс - чемпионаты шко...             0
# 1  премьер - министр михаил мишустин предложить я...             1
# 2  сегодня публикация предметный рейтинг " искусс...             0
# 3  компания яндекс создать консультативный совет ...             1
# 4  абитуриент ждать увеличение бюджетный место , ...             2
# 5  до 5 ноябрь продолжаться приём на совместный п...             1
# 6  29 - 30 октябрь в онлайн - формате пройти юбил...             2
# 7  ниу вшэ вручить ежегодный премия " импульс доб...             1
#
#                                        gold_keywords  \
# 0  {кейс-чемпионат школьников, предпринимательств...
# 1  {ярослав кузьминов, экспертное сообщество, экс...
# 2  {предмет, академический рейтинг мировых универ...
# 3  {консультативный совет, ярослав кузьминов, экс...
# 4  {вступительные испытания, программа, бакалаври...
# 5  {спортивный, спортивный менеджмент, проект, сп...
# 6  {международное сотрудничество, финансовый, раб...
# 7  {фонд «наше будущее», социальный, «импульс доб...
#
#                                        rake_keywords  \
# 0  [президент московский торгово, региональный ке...
# 1  [ведущий вуз страна, учитывать ваш опыт, экспе...
# 2  [мировой рейтинг, гуманитарный наука, год, qs,...
# 3  [игорь агамирзян, экономический институт, проф...
# 4  [управление стратегический коммуникация, между...
# 5  [высокий школа экономика, спортивный менеджмен...
# 6  [финансовый экономика, международный уровень, ...
# 7  [программа профессиональный переподготовка, сф...
#
#                                    textrank_keywords  \
# 0  [команда, бизнес, чемпионаты, чемпионат, регио...
# 1  [ярослав, правительство, это, работа, новый, д...
# 2  [хороший, вшэ, предметный рейтинг, год высокий...
# 3  [экосистема, экосистемы, яндекс, цифровой, кон...
# 4  [программа, программы, программ, программам, п...
# 5  [продолжать, ноябрь продолжаться приём, готовы...
# 6  [конференция, работа, участник, стать, статья,...
# 7  [свой, социальный предпринимательство, обществ...
#
#                                       tfidf_keywords
# 0  [кейс, чемпионат, победитель, палата, московск...
# 1  [экспертный, ярослав, министр, правительство, ...
# 2  [рейтинг, предметный, топ, qs, год, университе...
# 3  [экосистема, яндекс, совет, консультативный, ц...
# 4  [бакалавриат, абитуриент, программа, приём, мо...
# 5  [спортивный, программа, менеджмент, знание, се...
# 6  [конференция, финансовый, участник, миэф, учён...
# 7  [социальный, премия, наш, предпринимательство,...

# %% [markdown]
# ## Фильтрация

# %% [markdown]
# По-моему, в качестве ключевых слов плохо подходят глаголы, а также сочетания больше двух существительных. Отфильтруем их:

# %%
def filter_keywords(kws: List[str]) -> List[str]:
    filtered_kws = []
    for kw in kws:
        kw_doc = nlp(kw)
        noun_count = 0
        for token in kw_doc:
            if token.pos_ == 'VERB':
                break
            elif token.pos_ == 'NOUN':
                noun_count += 1
            if noun_count >= 3:
                break
        else:
            filtered_kws.append(kw)
    return filtered_kws

# %% [markdown]
# ## Метрики

# %%
def compute_metrics(gold_kws: Iterable[Iterable[str]], pred_kws: Iterable[Iterable[str]]) -> Dict:
    n_samples = len(gold_kws)
    precision_avg = []
    recall_avg = []
    f1_avg = []
    for g, p in zip(gold_kws, pred_kws):
        g = set(g)
        p = set(p)
        tp = len(g.intersection(p))
        if tp == 0:
            precision = 0
            recall = 0
            f1 = 0
        else:
            precision = tp / len(p)
            recall = tp / len(g)
            f1 = 2 * precision * recall / (precision + recall)
        precision_avg.append(precision)
        recall_avg.append(recall)
        f1_avg.append(f1)
    precision_avg = sum(precision_avg) / n_samples
    recall_avg = sum(recall_avg) / n_samples
    f1_avg = sum(f1_avg) / n_samples
    return {'precision': precision_avg, 'recall': recall_avg, 'f1_score': f1_avg}

# %%
methods = ['rake', 'textrank', 'tfidf']

# %% [markdown]
# ### Без фильтра

# %%
for m in methods:
    metrics = compute_metrics(corpus['gold_keywords'], corpus[f'{m}_keywords'])
    print(m)
    print(metrics)
# Out:
# rake
# {'precision': 0.08735225927070059, 'recall': 0.14346070596070595, 'f1_score': 0.10173615390936357}
# textrank
# {'precision': 0.06875320935103543, 'recall': 0.28146853146853146, 'f1_score': 0.10891194120603467}
# tfidf
# {'precision': 0.21874999999999997, 'recall': 0.36401098901098905, 'f1_score': 0.27207210067148396}

# %% [markdown]
# ### С фильтром

# %%
for m in methods:
    metrics = compute_metrics(corpus['gold_keywords'].apply(filter_keywords), corpus[f'{m}_keywords'].apply(filter_keywords))
    print(m)
    print(metrics)
# Out:
# rake
# {'precision': 0.09607546311566267, 'recall': 0.15802947052947056, 'f1_score': 0.11385787701577177}
# textrank
# {'precision': 0.08989398711920264, 'recall': 0.3066433566433566, 'f1_score': 0.13562403807676918}
# tfidf
# {'precision': 0.23028250773993808, 'recall': 0.4053613053613054, 'f1_score': 0.29120519821298463}

# %% [markdown]
# ## Ошибки методов выделения ключевых слов

# %% [markdown]
# Добавление морфологических фильтров позволяет немного повысить метрики.
#
# В ключевые слова, выделенные TextRank, могут попадать разные формы одного и того же слова:

# %%
corpus['textrank_keywords'][4][:10]
# Out:
# ['программа',
#  'программы',
#  'программ',
#  'программам',
#  'программу',
#  'москва',
#  'год',
#  'приём',
#  'прием',
#  'свой']

# %% [markdown]
# Это можно решить более точной лемматизацией.
#
# В ключевых словах Rake встречаются длинные специфические словосочетания вроде *учитывать ваш опыт*:

# %%
corpus['rake_keywords'][1]
# Out:
# ['ведущий вуз страна',
#  'учитывать ваш опыт',
#  'экспертный совет',
#  'экспертный сообщество',
#  'это',
#  'правительство',
#  'проект',
#  'министр',
#  'экономика',
#  'премьер',
#  'подчеркнуть',
#  'число',
#  'хотеть']

# %% [markdown]
# Возможно, это можно решить, подобрав параметры модели Rake.
#
# В целом, методы плохо выделяют частотные слова, которые, тем не менее, несут смысл и являются рамочными для текста (в данном корпусе это слово *университет* и подобные).
